# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "../build/applications/iridium_4step_out.hdf5"

# %%
f = h5py.File(filename, 'r')
data = f['data'][:]
f.close()

# %%
# Solution at time 0.9
data_row = data[9,:]
time = data_row[0]
psd = data_row[4:]
plt.plot(psd)
plt.xlabel("Number of atoms")
plt.show()

# %%
# Solution at time 1.2
data_row = data[12,:]
time = data_row[0]
psd = data_row[4:]
plt.plot(psd)
plt.xlabel("Number of atoms")
plt.show()

# %%
# Solution at time 2.3
data_row = data[23,:]
time = data_row[0]
psd = data_row[4:]
plt.plot(psd)
plt.xlabel("Number of atoms")
plt.show()

# %%
# Solution at time 4.8
data_row = data[48,:]
time = data_row[0]
psd = data_row[4:]
plt.plot(psd)
plt.xlabel("Number of atoms")
plt.show()
